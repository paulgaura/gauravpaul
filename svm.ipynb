# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go


import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:/Users/VEDPAL SINGH/Desktop/Mobile Classification.csv")

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
plt.figure(figsize=(20,9))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='PuBu')
# Out:
# <Axes: >

# %%
df.corr().sort_values(by=)
# Out:
#   Cell In[24], line 1
#     df.corr().sort_values(by=)
#                              ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.price_range.value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %%
sns.scatterplot(x=df.ram,y=df.mobile_wt,hue=df.price_range,palette="dark")
# Out:
# <Axes: xlabel='ram', ylabel='mobile_wt'>

# %%
sns.displot(df.ram)

# %%
x = df.drop('price_range',axis=1)

# %%
y=df.price_range

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1400, 20)
# (600, 20)
# (1400,)
# (600,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr
# Out:
# LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([2, 2, 3, 1, 1, 1, 1, 1, 0, 0, 0, 0, 1, 0, 1, 1, 1, 1, 0, 1, 3, 1,
#        3, 2, 3, 2, 2, 1, 0, 0, 2, 2, 0, 0, 3, 0, 1, 0, 0, 1, 0, 3, 3, 3,
#        3, 1, 1, 2, 3, 1, 0, 2, 3, 2, 3, 3, 1, 3, 2, 3, 3, 3, 3, 1, 3, 0,
#        0, 1, 0, 2, 2, 1, 3, 2, 3, 3, 3, 2, 0, 1, 0, 0, 2, 1, 2, 3, 1, 2,
#        0, 0, 3, 3, 0, 1, 0, 3, 2, 0, 1, 3, 1, 1, 3, 3, 0, 3, 0, 0, 3, 0,
#        1, 0, 3, 1, 2, 3, 2, 3, 1, 0, 3, 3, 3, 3, 2, 2, 3, 3, 1, 1, 0, 0,
#        0, 1, 0, 1, 3, 0, 3, 2, 3, 3, 0, 1, 0, 1, 1, 3, 3, 0, 2, 1, 2, 1,
#        3, 1, 2, 1, 3, 1, 1, 1, 2, 2, 1, 2, 1, 1, 3, 3, 1, 3, 1, 3, 2, 2,
#        2, 3, 3, 3, 1, 1, 1, 0, 3, 3, 1, 2, 0, 2, 1, 0, 3, 3, 0, 1, 0, 0,
#        3, 0, 0, 1, 3, 2, 2, 3, 0, 3, 2, 3, 1, 2, 2, 3, 0, 3, 0, 1, 3, 1,
#        1, 2, 3, 0, 1, 2, 2, 1, 3, 2, 1, 1, 0, 1, 0, 3, 0, 3, 2, 0, 3, 1,
#        1, 3, 0, 3, 2, 1, 3, 3, 2, 3, 1, 2, 3, 1, 0, 2, 0, 0, 1, 3, 3, 0,
#        0, 0, 1, 2, 1, 3, 2, 1, 3, 1, 2, 3, 2, 3, 1, 3, 2, 3, 1, 2, 3, 3,
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.625

# %%
from sklearn.svm import SVC

# %%
algo=SVC(random_state=1)

# %%
algo.fit(x_train,y_train)
# Out:
# SVC(random_state=1)

# %%
algo.score(x_train,y_train)
algo.score(x_test,y_test)
# Out:
# 0.945

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
x_test["prediction lr"]=y_pred
